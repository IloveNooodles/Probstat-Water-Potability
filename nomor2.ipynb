# %% [markdown]
# 2. Membuat Visualisasi plot distribusi, dalam bentuk histogram dan boxplot untuk setiap
# kolom numerik. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot
# tersebut

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

col_names = ['id', 'pH', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'OrganicCarbon', 'Trihalomethanes', 'Turbidity', 'Potability']
df = pd.read_csv('water_potability.csv', names=col_names)

# %%
# histogram atribut id
df.hist(column='id')
# Out:
# array([[<AxesSubplot:title={'center':'id'}>]], dtype=object)

# %%
df.boxplot(column='id')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='pH')

# %%
df.boxplot(column='pH')

# %%
df.hist(column='Hardness')

# %%
df.boxplot(column='Hardness')

# %%
df.hist(column='Solids')

# %%
df.boxplot(column='Solids')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Chloramines')
# Out:
# array([[<AxesSubplot:title={'center':'Chloramines'}>]], dtype=object)

# %%
df.boxplot(column='Chloramines')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Sulfate')
# Out:
# array([[<AxesSubplot:title={'center':'Sulfate'}>]], dtype=object)

# %%
df.boxplot(column='Sulfate')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Conductivity')
# Out:
# array([[<AxesSubplot:title={'center':'Conductivity'}>]], dtype=object)

# %%
df.boxplot(column='Conductivity')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='OrganicCarbon')
# Out:
# array([[<AxesSubplot:title={'center':'OrganicCarbon'}>]], dtype=object)

# %%
df.boxplot(column='OrganicCarbon')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Trihalomethanes')
# Out:
# array([[<AxesSubplot:title={'center':'Trihalomethanes'}>]], dtype=object)

# %%
df.boxplot(column='Trihalomethanes')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Turbidity')
# Out:
# array([[<AxesSubplot:title={'center':'Turbidity'}>]], dtype=object)

# %%
df.boxplot(column='Turbidity')
# Out:
# <AxesSubplot:>

# %%
df.hist(column='Potability')
# Out:
# array([[<AxesSubplot:title={'center':'Potability'}>]], dtype=object)

# %%
df.boxplot(column='Potability')
