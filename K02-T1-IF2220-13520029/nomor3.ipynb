# %% [markdown]
# ### No 3
# Menentukan setiap kolom numerik berdistribusi normal atau tidak

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

col_names = ['id', 'pH', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'OrganicCarbon', 'Trihalomethanes', 'Turbidity', 'Potability']
df = pd.read_csv('../data/water_potability.csv', names=col_names)
df.drop(["id", "Potability"], axis=1)

# %% [markdown]
# Menentukan setiap kolom numerik berdistribusi normal atau tidak. Gunakan normality test
# yang dikaitkan dengan histogram plot.

# %%
for i in range(1, 10):
    stat, p = st.normaltest(df[col_names[i]])
    plt.subplots()
    mu, sigma = df[col_names[i]].mean(), df[col_names[i]].std()
    alpha = 0.05

    # plot distribution
    count, bins, ignored = plt.hist(df[col_names[i]], 30, density=True)
    plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
             np.exp(- (bins - mu)**2 / (2 * sigma**2)),
             linewidth=2, color='red')
    print(f"Nilai p ialah: {p}")
    if p <= alpha:
        print(col_names[i] + ' tidak berdistribusi normal')
    else:
        print(col_names[i] + ' berdistribusi normal')
    plt.show()
# Out:
# Nilai p ialah: 2.651481334679772e-05
# pH tidak berdistribusi normal
# Nilai p ialah: 0.00013442428699593801
# Hardness tidak berdistribusi normal
# Nilai p ialah: 2.079661368874404e-24
# Solids tidak berdistribusi normal
# Nilai p ialah: 0.0002504831654753917
# Chloramines tidak berdistribusi normal
# Nilai p ialah: 4.425593667801525e-07
# Sulfate tidak berdistribusi normal
# Nilai p ialah: 4.3901807828785e-07
# Conductivity tidak berdistribusi normal
# Nilai p ialah: 0.8825496581408321
# OrganicCarbon berdistribusi normal
# Nilai p ialah: 0.1043598441875188
# Trihalomethanes berdistribusi normal
# Nilai p ialah: 0.7694717369961119
# Turbidity berdistribusi normal
